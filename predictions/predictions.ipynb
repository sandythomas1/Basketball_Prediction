# %%
import pandas as pd

preds = pd.read_csv(
    "data/processed/model_predictions.csv",
    parse_dates=["game_date"]
)

preds.sort_values("model_prob_home").head(10)
# Out:
# Running cells with 'tf_blackwell (Python 3.11.14)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n tf_blackwell ipykernel --update-deps --force-reinstall'

# %%
preds.sort_values("model_prob_home", ascending=False).head(10)
