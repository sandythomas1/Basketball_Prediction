# %% [markdown]
# Initial basketball game prediction model

# %% [markdown]
# 'BallDon'tLie' API pull

# %%
import requests
import pandas as pd

# Define your API key
api_key = '4ee8f201-85ee-49d2-b700-149393e21960'

# Set up the base URL and headers
base_url = 'https://api.balldontlie.io/v1'
headers = {'Authorization': api_key}

# Example: Get games data
response = requests.get(f'{base_url}/games', headers=headers)

# Check if request was successful
if response.status_code == 200:
    games_data = response.json()
    print("Data retrieved successfully!")
    print(games_data)
else:
    print(f"Error: {response.status_code}")
# Out:
# Data retrieved successfully!
# {'data': [{'id': 874129, 'date': '1946-11-01', 'season': 1946, 'status': 'Final', 'period': 4, 'time': None, 'postseason': False, 'home_team_score': 66, 'visitor_team_score': 68, 'datetime': None, 'home_q1': None, 'home_q2': None, 'home_q3': None, 'home_q4': None, 'home_ot1': None, 'home_ot2': None, 'home_ot3': None, 'home_timeouts_remaining': None, 'home_in_bonus': None, 'visitor_q1': None, 'visitor_q2': None, 'visitor_q3': None, 'visitor_q4': None, 'visitor_ot1': None, 'visitor_ot2': None, 'visitor_ot3': None, 'visitor_timeouts_remaining': None, 'visitor_in_bonus': None, 'home_team': {'id': 41, 'conference': '    ', 'division': '', 'city': '', 'name': 'Toronto Huskies', 'full_name': 'Toronto Huskies', 'abbreviation': 'HUS'}, 'visitor_team': {'id': 20, 'conference': 'East', 'division': 'Atlantic', 'city': 'New York', 'name': 'Knicks', 'full_name': 'New York Knicks', 'abbreviation': 'NYK'}}, {'id': 874125, 'date': '1946-11-02', 'season': 1946, 'status': 'Final', 'period': 4, 'time': None, 'postseason': False, 'home_team_score': 63, 'visitor_team_score': 47, 'datetime': None, 'home_q1': None, 'home_q2': None, 'home_q3': None, 'home_q4': None, 'home_ot1': None, 'home_ot2': None, 'home_ot3': None, 'home_timeouts_remaining': None, 'home_in_bonus': None, 'visitor_q1': None, 'visitor_q2': None, 'visitor_q3': None, 'visitor_q4': None, 'visitor_ot1': None, 'visitor_ot2': None, 'visitor_ot3': None, 'visitor_timeouts_remaining': None, 'visitor_in_bonus': None, 'home_team': {'id': 37, 'conference': '    ', 'division': '', 'city': '', 'name': 'Chicago Stags', 'full_name': 'Chicago Stags', 'abbreviation': 'CHS'}, 'visitor_team': {'id': 20, 'conference': 'East', 'division': 'Atlantic', 'city': 'New York', 'name': 'Knicks', 'full_name': 'New York Knicks', 'abbreviation': 'NYK'}}, {'id': 874126, 'date': '1946-11-02', 'season': 1946, 'status': 'Final', 'period': 4, 'time': None, 'postseason': False, 'home_team_score': 59, 'visitor_team_score': 53, 'datetime': None, 'home_q1': None, 'home_q2': None, 'home_q3': None, 'home_q4': None, 'home_ot1': None, 'home_ot2': None, 'home_ot3': None, 'home_timeouts_remaining': None, 'home_in_bonus': None, 'visitor_q1': None, 'visitor_q2': None, 'visitor_q3': None, 'visitor_q4': None, 'visitor_ot1': None, 'visitor_ot2': None, 'visitor_ot3': None, 'visitor_timeouts_remaining': None, 'visitor_in_bonus': None, 'home_team': {'id': 43, 'conference': '    ', 'division': '', 'city': '', 'name': 'Providence Steamrollers', 'full_name': 'Providence Steamrollers', 'abbreviation': 'PRO'}, 'visitor_team': {'id': 2, 'conference': 'East', 'division': 'Atlantic', 'city': 'Boston', 'name': 'Celtics', 'full_name': 'Boston Celtics', 'abbreviation': 'BOS'}}, {'id': 874127, 'date': '1946-11-02', 'season': 1946, 'status': 'Final', 'period': 4, 'time': None, 'postseason': False, 'home_team_score': 56, 'visitor_team_score': 51, 'datetime': None, 'home_q1': None, 'home_q2': None, 'home_q3': None, 'home_q4': None, 'home_ot1': None, 'home_ot2': None, 'home_ot3': None, 'home_timeouts_remaining': None, 'home_in_bonus': None, 'visitor_q1': None, 'visitor_q2': None, 'visitor_q3': None, 'visitor_q4': None, 'visitor_ot1': None, 'visitor_ot2': None, 'visitor_ot3': None, 'visitor_timeouts_remaining': None, 'visitor_in_bonus': None, 'home_team': {'id': 38, 'conference': '    ', 'division': '', 'city': '', 'name': 'St. Louis Bombers', 'full_name': 'St. Louis Bombers', 'abbreviation': 'BOM'}, 'visitor_team': {'id': 44, 'conference': '    ', 'division': '', 'city': '', 'name': 'Pittsburgh Ironmen', 'full_name': 'Pittsburgh Ironmen', 'abbreviation': 'PIT'}}, {'id': 874128, 'date': '1946-11-02', 'season': 1946, 'status': 'Final', 'period': 4, 'time': None, 'postseason': False, 'home_team_score': 33, 'visitor_team_score': 50, 'datetime': None, 'home_q1': None, 'home_q2': None, 'home_q3': None, 'home_q4': None, 'home_ot1': None, 'home_ot2': None, 'home_ot3': None, 'home_timeouts_remaining': None, 'home_in_bonus': None, 'visitor_q1': None, 'visitor_q2': ...
